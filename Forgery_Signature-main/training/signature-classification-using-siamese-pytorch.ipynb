# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd 
import torchvision.models as models

# %% [markdown]
# ### Additional Utility Functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# First, look at everything.
from subprocess import check_output
print(check_output(["ls", "../input/sign_data/sign_data"]).decode("utf8"))
# Out:
# test
# test_data.csv
# train
# train_data.csv

# %%
class Config():
    training_dir = "../input/sign_data/sign_data/train"
    testing_dir = "../input/sign_data/sign_data/test"
    train_batch_size = 32
    train_number_epochs = 50

# %%
training_dir="../input/sign_data/sign_data/train"
training_csv="../input/sign_data/sign_data/train_data.csv"
testing_csv="../input/sign_data/sign_data/test_data.csv"
testing_dir="../input/sign_data/sign_data/test"

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((224,224)),
                                                                      transforms.RandomRotation(10),
                                                                      transforms.ToTensor(),
                                                                      transforms.Normalize(mean=[0.485], std=[0.229])
                                                                      ])
                                       )

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]]

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Use ResNet18 as backbone for better performance
        self.backbone = models.resnet18(pretrained=False)
        # Modify for 1 channel input
        self.backbone.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Replace the fully connected layer to output 128-dimensional embedding
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, 128)
        
    def forward_once(self, x):
        return self.backbone(x)
        
    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):


    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ### Train the Model

# %%
# Load the dataset as pytorch tensors using dataloader
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
# Check whether you have GPU is loaded or not
if torch.cuda.is_available():
    print('Yes')
# Out:
# Yes

# %%
# Declare Siamese Network
net = SiameseNetwork().cuda()
# Decalre Loss Function
criterion = ContrastiveLoss()
# Declare Optimizer - using Adam for better convergence
optimizer = optim.Adam(net.parameters(), lr=1e-4, weight_decay=1e-5)

# %%
def train():
    counter = []
    loss_history = [] 
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# Epoch number 0
#  Current loss 1.4935362339019775
#
# Epoch number 0
#  Current loss 1.52217698097229
#
# Epoch number 0
#  Current loss 1.3264203071594238
#
# Epoch number 0
#  Current loss 1.1861568689346313
#
# Epoch number 0
#  Current loss 1.2457375526428223
#
# Epoch number 0
#  Current loss 1.3522186279296875
#
# Epoch number 0
#  Current loss 0.898525059223175
#
# Epoch number 0
#  Current loss 1.4156666994094849
#
# Epoch number 0
#  Current loss 1.1099077463150024
#
# Epoch number 0
#  Current loss 1.0446125268936157
#
# Epoch number 0
#  Current loss 1.080963134765625
#
# Epoch number 0
#  Current loss 1.0439599752426147
#
# Epoch number 0
#  Current loss 1.1460044384002686
#
# Epoch number 0
#  Current loss 1.3110239505767822
#
# Epoch number 0
#  Current loss 1.087827205657959
#
# Epoch number 1
#  Current loss 1.0629425048828125
#
# Epoch number 1
#  Current loss 1.3233895301818848
#
# Epoch number 1
#  Current loss 1.5127605199813843
#
# Epoch number 1
#  Current loss 1.2076622247695923
#
# Epoch number 1
#  Current loss 1.1358680725097656
#
# Epoch number 1
#  Current loss 1.3003365993499756
#
# Epoch number 1
#  Current loss 1.3360142707824707
#
# Epoch number 1
#  Current loss 1.3403326272964478
#
# Epoch number 1
#  Current loss 1.1425879001617432
#
# Epoch number 1
#  Current loss 0.8689241409301758
#
# Epoch number 1
#  Current loss 1.1586532592773438
#
# Epoch number 1
#  Current loss 1.3422505855560303
#
# Epoch number 1
#  Current loss 1.1749454736709595
#
# Epoch number 1
#  Current loss 1.1190929412841797
#
# Epoch number 1
#  Current loss 1.3311389684677124
#
# Epoch number 2
#  Current loss 1.2238966226577759
#
# Epoch number 2
#  Current loss 1.0592329502105713
#
# Epoch number 2
#  Current loss 1.4060899019241333
#
# Epoch number 2
#  Current loss 1.1245410442352295
#
# Epoch number 2
#  Current loss 1.3094334602355957
#
# Epoch number 2
#  Current loss 1.2889764308929443
#
# Epoch number 2
#  Current loss 1.0939226150512695
#
# Epoch number 2
#  Current loss 1.1300041675567627
#
# Epoch number 2
#  Current loss 1.3348283767700195
#
# Epoch number 2
#  Current loss 1.1536377668380737
#
# Epoch number 2
#  Current loss 0.9847742319107056
#
# Epoch number 2
#  Current loss 0.7360543012619019
#
# Epoch number 2
#  Current loss 1.3771919012069702
#
# Epoch number 2
#  Current loss 1.340256690979004
#
# Epoch number 2
#  Current loss 1.42079758644104
#
# Epoch number 3
#  Current loss 1.3562853336334229
#
# Epoch number 3
#  Current loss 1.1998207569122314
#
# Epoch number 3
#  Current loss 1.3633767366409302
#
# Epoch number 3
#  Current loss 1.1923198699951172
#
# Epoch number 3
#  Current loss 1.202687382698059
#
# Epoch number 3
#  Current loss 1.0988657474517822
#
# Epoch number 3
#  Current loss 1.1903643608093262
#
# Epoch number 3
#  Current loss 1.1809442043304443
#
# Epoch number 3
#  Current loss 1.1831977367401123
#
# Epoch number 3
#  Current loss 1.1771174669265747
#
# Epoch number 3
#  Current loss 1.2196539640426636
#
# Epoch number 3
#  Current loss 1.0502521991729736
#
# Epoch number 3
#  Current loss 1.4484624862670898
#
# Epoch number 3
#  Current loss 1.1346379518508911
#
# Epoch number 3
#  Current loss 1.1689635515213013
#
# Epoch number 4
#  Current loss 1.6549758911132812
#
# Epoch number 4
#  Current loss 1.1175228357315063
#
# Epoch number 4
#  Current loss 1.2666186094284058
#
# Epoch number 4
#  Current loss 1.3992805480957031
#
# Epoch number 4
#  Current loss 1.2277953624725342
#
# Epoch number 4
#  Current loss 1.2992068529129028
#
# Epoch number 4
#  Current loss 1.2308928966522217
#
# Epoch number 4
#  Current loss 1.286839246749878
#
# Epoch number 4
#  Current loss 1.2995977401733398
#
# Epoch number 4
#  Current loss 1.275606393814087
#
# Epoch number 4
#  Current loss 1.1327650547027588
#
# Epoch number 4
#  Current loss 1.4823777675628662
#
# Epoch number 4
#  Current loss 1.123577356338501
#
# Epoch number 4
#  Current loss 1.108569860458374
#
# Epoch number 4
#  Current loss 1.0098085403442383
#
# Epoch number 5
#  Current loss 1.4452731609344482
#
# Epoch number 5
#  Current loss 1.1863631010055542
#
# Epoch number 5
#  Current loss 1.204314947128296
#
# Epoch number 5
#  Current loss 1.3659210205078125
#
# Epoch number 5
#  Current loss 1.173149585723877
#
# Epoch number 5
#  Current loss 1.0511465072631836
#
# Epoch number 5
#  Current loss 1.2906827926635742
#
# Epoch number 5
#  Current loss 1.1093437671661377
#
# Epoch number 5
#  Current loss 1.1896374225616455
#
# Epoch number 5
#  Current loss 1.6398698091506958
#
# Epoch number 5
#  Current loss 1.2720212936401367
#
# Epoch number 5
#  Current loss 1.0822315216064453
#
# Epoch number 5
#  Current loss 1.17580246925354
#
# Epoch number 5
#  Current loss 1.2057690620422363
#
# Epoch number 5
#  Current loss 1.2738513946533203
#
# Epoch number 6
#  Current loss 1.5699589252471924
#
# Epoch number 6
#  Current loss 1.3564484119415283
#
# Epoch number 6
#  Current loss 1.2490313053131104
#
# Epoch number 6
#  Current loss 1.274078607559204
#
# Epoch number 6
#  Current loss 1.2188732624053955
#
# Epoch number 6
#  Current loss 1.3007968664169312
#
# Epoch number 6
#  Current loss 1.0722832679748535
#
# Epoch number 6
#  Current loss 1.15346360206604
#
# Epoch number 6
#  Current loss 1.252873182296753
#
# Epoch number 6
#  Current loss 1.0334938764572144
#
# Epoch number 6
#  Current loss 1.147824764251709
#
# Epoch number 6
#  Current loss 1.2037471532821655
#
# Epoch number 6
#  Current loss 1.2472853660583496
#
# Epoch number 6
#  Current loss 1.18845796585083
#
# Epoch number 6
#  Current loss 1.1691887378692627
#
# Epoch number 7
#  Current loss 1.0541296005249023
#
# Epoch number 7
#  Current loss 1.0921627283096313
#
# Epoch number 7
#  Current loss 1.295832633972168
#
# Epoch number 7
#  Current loss 1.0696380138397217
#
# Epoch number 7
#  Current loss 1.0911670923233032
#
# Epoch number 7
#  Current loss 1.4366211891174316
#
# Epoch number 7
#  Current loss 1.131833791732788
#
# Epoch number 7
#  Current loss 1.2283079624176025
#
# Epoch number 7
#  Current loss 1.067327857017517
#
# Epoch number 7
#  Current loss 1.2149932384490967
#
# Epoch number 7
#  Current loss 1.2654380798339844
#
# Epoch number 7
#  Current loss 1.1876552104949951
#
# Epoch number 7
#  Current loss 1.388880968093872
#
# Epoch number 7
#  Current loss 1.0796252489089966
#
# Epoch number 7
#  Current loss 1.1125434637069702
#
# Epoch number 8
#  Current loss 1.146751880645752
#
# Epoch number 8
#  Current loss 1.5323233604431152
#
# Epoch number 8
#  Current loss 1.2997316122055054
#
# Epoch number 8
#  Current loss 1.310141921043396
#
# Epoch number 8
#  Current loss 1.2268811464309692
#
# Epoch number 8
#  Current loss 1.1691460609436035
#
# Epoch number 8
#  Current loss 1.1585361957550049
#
# Epoch number 8
#  Current loss 1.227697491645813
#
# Epoch number 8
#  Current loss 1.1563615798950195
#
# Epoch number 8
#  Current loss 1.2419462203979492
#
# Epoch number 8
#  Current loss 1.4179797172546387
#
# Epoch number 8
#  Current loss 1.5619868040084839
#
# Epoch number 8
#  Current loss 1.0270308256149292
#
# Epoch number 8
#  Current loss 1.2522203922271729
#
# Epoch number 8
#  Current loss 1.2804863452911377
#
# Epoch number 9
#  Current loss 1.1539782285690308
#
# Epoch number 9
#  Current loss 1.3351285457611084
#
# Epoch number 9
#  Current loss 1.263090968132019
#
# Epoch number 9
#  Current loss 1.500577688217163
#
# Epoch number 9
#  Current loss 1.0789990425109863
#
# Epoch number 9
#  Current loss 1.2214245796203613
#
# Epoch number 9
#  Current loss 1.0944968461990356
#
# Epoch number 9
#  Current loss 1.3978153467178345
#
# Epoch number 9
#  Current loss 1.13846755027771
#
# Epoch number 9
#  Current loss 1.3581360578536987
#
# Epoch number 9
#  Current loss 1.0118639469146729
#
# Epoch number 9
#  Current loss 1.24144446849823
#
# Epoch number 9
#  Current loss 1.1733871698379517
#
# Epoch number 9
#  Current loss 1.5350010395050049
#
# Epoch number 9
#  Current loss 1.2514771223068237
#
# Epoch number 10
#  Current loss 1.2592072486877441
#
# Epoch number 10
#  Current loss 1.1535323858261108
#
# Epoch number 10
#  Current loss 1.5042657852172852
#
# Epoch number 10
#  Current loss 1.14850652217865
#
# Epoch number 10
#  Current loss 1.283638596534729
#
# Epoch number 10
#  Current loss 1.047260046005249
#
# Epoch number 10
#  Current loss 1.0487191677093506
#
# Epoch number 10
#  Current loss 1.1083431243896484
#
# Epoch number 10
#  Current loss 1.1964969635009766
#
# Epoch number 10
#  Current loss 1.462446928024292
#
# Epoch number 10
#  Current loss 1.388258695602417
#
# Epoch number 10
#  Current loss 1.3116695880889893
#
# Epoch number 10
#  Current loss 1.2697033882141113
#
# Epoch number 10
#  Current loss 1.0605823993682861
#
# Epoch number 10
#  Current loss 1.1343376636505127
#
# Epoch number 11
#  Current loss 1.0392522811889648
#
# Epoch number 11
#  Current loss 1.0079174041748047
#
# Epoch number 11
#  Current loss 1.2779396772384644
#
# Epoch number 11
#  Current loss 1.231921672821045
#
# Epoch number 11
#  Current loss 1.2094618082046509
#
# Epoch number 11
#  Current loss 1.188800573348999
#
# Epoch number 11
#  Current loss 1.0010631084442139
#
# Epoch number 11
#  Current loss 2.033186912536621
#
# Epoch number 11
#  Current loss 1.010679006576538
#
# Epoch number 11
#  Current loss 1.1090574264526367
#
# Epoch number 11
#  Current loss 1.1861844062805176
#
# Epoch number 11
#  Current loss 1.1263408660888672
#
# Epoch number 11
#  Current loss 1.2573661804199219
#
# Epoch number 11
#  Current loss 1.4261703491210938
#
# Epoch number 11
#  Current loss 1.0394034385681152
#
# Epoch number 12
#  Current loss 1.5448458194732666
#
# Epoch number 12
#  Current loss 1.2604037523269653
#
# Epoch number 12
#  Current loss 1.3178133964538574
#
# Epoch number 12
#  Current loss 0.9556989073753357
#
# Epoch number 12
#  Current loss 1.286283254623413
#
# Epoch number 12
#  Current loss 1.0558197498321533
#
# Epoch number 12
#  Current loss 1.0534336566925049
#
# Epoch number 12
#  Current loss 1.4773682355880737
#
# Epoch number 12
#  Current loss 1.3437596559524536
#
# Epoch number 12
#  Current loss 1.1861989498138428
#
# Epoch number 12
#  Current loss 1.441070556640625
#
# Epoch number 12
#  Current loss 1.0712049007415771
#
# Epoch number 12
#  Current loss 1.006058931350708
#
# Epoch number 12
#  Current loss 0.9738839864730835
#
# Epoch number 12
#  Current loss 1.2280049324035645
#
# Epoch number 13
#  Current loss 1.1911578178405762
#
# Epoch number 13
#  Current loss 1.0978171825408936
#
# Epoch number 13
#  Current loss 1.2954429388046265
#
# Epoch number 13
#  Current loss 1.0533397197723389
#
# Epoch number 13
#  Current loss 1.3886191844940186
#
# Epoch number 13
#  Current loss 1.1972700357437134
#
# Epoch number 13
#  Current loss 1.3253648281097412
#
# Epoch number 13
#  Current loss 1.42616868019104
#
# Epoch number 13
#  Current loss 1.6070148944854736
#
# Epoch number 13
#  Current loss 1.096966028213501
#
# Epoch number 13
#  Current loss 1.3305423259735107
#
# Epoch number 13
#  Current loss 1.2558178901672363
#
# Epoch number 13
#  Current loss 1.230534553527832
#
# Epoch number 13
#  Current loss 1.3235880136489868
#
# Epoch number 13
#  Current loss 1.3599514961242676
#
# Epoch number 14
#  Current loss 1.274275779724121
#
# Epoch number 14
#  Current loss 1.1314506530761719
#
# Epoch number 14
#  Current loss 1.402726173400879
#
# Epoch number 14
#  Current loss 1.205970048904419
#
# Epoch number 14
#  Current loss 1.2806012630462646
#
# Epoch number 14
#  Current loss 1.1792047023773193
#
# Epoch number 14
#  Current loss 1.0875613689422607
#
# Epoch number 14
#  Current loss 1.0623838901519775
#
# Epoch number 14
#  Current loss 1.15975022315979
#
# Epoch number 14
#  Current loss 1.137818694114685
#
# Epoch number 14
#  Current loss 1.2393603324890137
#
# Epoch number 14
#  Current loss 1.1930694580078125
#
# Epoch number 14
#  Current loss 1.4341084957122803
#
# Epoch number 14
#  Current loss 1.440213680267334
#
# Epoch number 14
#  Current loss 1.0946125984191895
#
# Epoch number 15
#  Current loss 1.2854174375534058
#
# Epoch number 15
#  Current loss 1.1988965272903442
#
# Epoch number 15
#  Current loss 1.0889248847961426
#
# Epoch number 15
#  Current loss 1.084801435470581
#
# Epoch number 15
#  Current loss 1.1864020824432373
#
# Epoch number 15
#  Current loss 1.0759400129318237
#
# Epoch number 15
#  Current loss 1.267688512802124
#
# Epoch number 15
#  Current loss 1.2614285945892334
#
# Epoch number 15
#  Current loss 1.3120543956756592
#
# Epoch number 15
#  Current loss 1.2073724269866943
#
# Epoch number 15
#  Current loss 1.450577735900879
#
# Epoch number 15
#  Current loss 1.2509233951568604
#
# Epoch number 15
#  Current loss 1.210991382598877
#
# Epoch number 15
#  Current loss 0.9953351020812988
#
# Epoch number 15
#  Current loss 1.1794157028198242
#
# Epoch number 16
#  Current loss 1.1764041185379028
#
# Epoch number 16
#  Current loss 1.2055563926696777
#
# Epoch number 16
#  Current loss 1.2992676496505737
#
# Epoch number 16
#  Current loss 1.2931568622589111
#
# Epoch number 16
#  Current loss 1.1694155931472778
#
# Epoch number 16
#  Current loss 1.0818402767181396
#
# Epoch number 16
#  Current loss 1.1469531059265137
#
# Epoch number 16
#  Current loss 1.4424006938934326
#
# Epoch number 16
#  Current loss 1.152462124824524
#
# Epoch number 16
#  Current loss 1.1734271049499512
#
# Epoch number 16
#  Current loss 1.1298108100891113
#
# Epoch number 16
#  Current loss 1.0689237117767334
#
# Epoch number 16
#  Current loss 1.11587655544281
#
# Epoch number 16
#  Current loss 0.9351987838745117
#
# Epoch number 16
#  Current loss 1.1317024230957031
#
# Epoch number 17
#  Current loss 1.178627848625183
#
# Epoch number 17
#  Current loss 1.3151144981384277
#
# Epoch number 17
#  Current loss 1.5004013776779175
#
# Epoch number 17
#  Current loss 1.0941088199615479
#
# Epoch number 17
#  Current loss 1.1030316352844238
#
# Epoch number 17
#  Current loss 1.1542264223098755
#
# Epoch number 17
#  Current loss 1.4860082864761353
#
# Epoch number 17
#  Current loss 1.2868233919143677
#
# Epoch number 17
#  Current loss 1.1380969285964966
#
# Epoch number 17
#  Current loss 1.2478666305541992
#
# Epoch number 17
#  Current loss 1.188751459121704
#
# Epoch number 17
#  Current loss 1.0962438583374023
#
# Epoch number 17
#  Current loss 1.1369609832763672
#
# Epoch number 17
#  Current loss 1.0698068141937256
#
# Epoch number 17
#  Current loss 1.150778889656067
#
# Epoch number 18
#  Current loss 1.360470175743103
#
# Epoch number 18
#  Current loss 1.232606053352356
#
# Epoch number 18
#  Current loss 1.114300012588501
#
# Epoch number 18
#  Current loss 1.289643406867981
#
# Epoch number 18
#  Current loss 1.325476884841919
#
# Epoch number 18
#  Current loss 1.22675359249115
#
# Epoch number 18
#  Current loss 1.061575174331665
#
# Epoch number 18
#  Current loss 1.0627379417419434
#
# Epoch number 18
#  Current loss 1.2534388303756714
#
# Epoch number 18
#  Current loss 1.198801875114441
#
# Epoch number 18
#  Current loss 1.1718474626541138
#
# Epoch number 18
#  Current loss 1.3589802980422974
#
# Epoch number 18
#  Current loss 1.2253108024597168
#
# Epoch number 18
#  Current loss 1.0545649528503418
#
# Epoch number 18
#  Current loss 1.2608205080032349
#
# Epoch number 19
#  Current loss 1.172910451889038
#
# Epoch number 19
#  Current loss 1.1059701442718506
#
# Epoch number 19
#  Current loss 1.1887164115905762
#
# Epoch number 19
#  Current loss 1.2159284353256226
#
# Epoch number 19
#  Current loss 1.3095530271530151
#
# Epoch number 19
#  Current loss 1.3688740730285645
#
# Epoch number 19
#  Current loss 1.0796533823013306
#
# Epoch number 19
#  Current loss 1.6615040302276611
#
# Epoch number 19
#  Current loss 1.249342679977417
#
# Epoch number 19
#  Current loss 1.163212537765503
#
# Epoch number 19
#  Current loss 1.371823787689209
#
# Epoch number 19
#  Current loss 1.5000872611999512
#
# Epoch number 19
#  Current loss 1.262608289718628
#
# Epoch number 19
#  Current loss 1.2573429346084595
#
# Epoch number 19
#  Current loss 1.3011571168899536
#
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("model.pt"))

# %%
# Load the test dataset
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((224,224)),
                                                                      transforms.ToTensor(),
                                                                      transforms.Normalize(mean=[0.485], std=[0.229])
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)

# %%
# Print the sample outputs to view its dissimilarity
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
  x0, x1 , label = data
  concatenated = torch.cat((x0,x1),0)
  output1,output2 = model(x0.to(device),x1.to(device))
  eucledian_distance = F.pairwise_distance(output1, output2)
  if label==list_0:
    label="Orginial"
  else:
    label="Forged"
  imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
  counter=counter+1
  if counter ==20:
     break

# %% [markdown]
# ## Final Touch

# %% [markdown]
# Thats it guys ! I am limited by time , computational power and knowledge .to get standard accuracy . But anyway this is the working code of Siamese Neural Network and you can try it for your own applications and dataset.
#
# Paper Reference: https://arxiv.org/pdf/1707.02131.pdf
#
# Thanks to Gupta Blog : https://hackernoon.com/one-shot-learning-with-siamese-networks-in-pytorch-8ddaab10340e
