# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd 
import torchvision.models as models

# %% [markdown]
# ### Additional Utility Functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# First, look at everything.
from subprocess import check_output
print(check_output(["ls", "../input/sign_data/sign_data"]).decode("utf8"))
# Out:
# test
# test_data.csv
# train
# train_data.csv

# %%
class Config():
    training_dir = "../input/sign_data/sign_data/train"
    testing_dir = "../input/sign_data/sign_data/test"
    train_batch_size = 64
    train_number_epochs = 30

# %%
training_dir="../input/sign_data/sign_data/train"
training_csv="../input/sign_data/sign_data/train_data.csv"
testing_csv="../input/sign_data/sign_data/test_data.csv"
testing_dir="../input/sign_data/sign_data/test"

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((224,224)),
                                                                      transforms.RandomRotation(10),
                                                                      transforms.ToTensor(),
                                                                      transforms.Normalize(mean=[0.485], std=[0.229])
                                                                      ])
                                       )

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Use ResNet18 as backbone for better performance
        self.backbone = models.resnet18(pretrained=False)
        # Modify for 1 channel input
        self.backbone.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Replace the fully connected layer to output 128-dimensional embedding
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, 128)
        
    def forward_once(self, x):
        return self.backbone(x)
        
    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):


    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ### Train the Model

# %%
# Load the dataset as pytorch tensors using dataloader
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
# Check whether you have GPU is loaded or not
if torch.cuda.is_available():
    print('Yes')
# Out:
# Yes

# %%
# Declare Siamese Network
net = SiameseNetwork().cuda()
# Decalre Loss Function
criterion = ContrastiveLoss()
# Declare Optimizer - using Adam for better convergence
optimizer = optim.Adam(net.parameters(), lr=1e-4, weight_decay=1e-5)

# %%
def train():
    counter = []
    loss_history = [] 
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# Epoch number 0
#  Current loss 2.037417411804199
#
# Epoch number 0
#  Current loss 1.003201961517334
#
# Epoch number 0
#  Current loss 0.9970869421958923
#
# Epoch number 0
#  Current loss 0.9962432384490967
#
# Epoch number 0
#  Current loss 1.029768705368042
#
# Epoch number 0
#  Current loss 0.9979567527770996
#
# Epoch number 0
#  Current loss 0.9976816177368164
#
# Epoch number 0
#  Current loss 0.9984802007675171
#
# Epoch number 1
#  Current loss 1.0043489933013916
#
# Epoch number 1
#  Current loss 1.009225845336914
#
# Epoch number 1
#  Current loss 0.9903839826583862
#
# Epoch number 1
#  Current loss 0.9915249347686768
#
# Epoch number 1
#  Current loss 1.002416729927063
#
# Epoch number 1
#  Current loss 0.9978361129760742
#
# Epoch number 1
#  Current loss 1.0493208169937134
#
# Epoch number 1
#  Current loss 1.0028104782104492
#
# Epoch number 2
#  Current loss 1.0165984630584717
#
# Epoch number 2
#  Current loss 0.9981076717376709
#
# Epoch number 2
#  Current loss 1.0049411058425903
#
# Epoch number 2
#  Current loss 0.9998271465301514
#
# Epoch number 2
#  Current loss 0.9685453176498413
#
# Epoch number 2
#  Current loss 0.9706820249557495
#
# Epoch number 2
#  Current loss 0.9859801530838013
#
# Epoch number 2
#  Current loss 0.9957721829414368
#
# Epoch number 3
#  Current loss 0.9887127876281738
#
# Epoch number 3
#  Current loss 1.0212481021881104
#
# Epoch number 3
#  Current loss 1.0139329433441162
#
# Epoch number 3
#  Current loss 0.9962868690490723
#
# Epoch number 3
#  Current loss 1.010687232017517
#
# Epoch number 3
#  Current loss 1.0193052291870117
#
# Epoch number 3
#  Current loss 1.0198092460632324
#
# Epoch number 3
#  Current loss 1.0057445764541626
#
# Epoch number 4
#  Current loss 0.9567559957504272
#
# Epoch number 4
#  Current loss 0.967461347579956
#
# Epoch number 4
#  Current loss 0.9923606514930725
#
# Epoch number 4
#  Current loss 0.9854166507720947
#
# Epoch number 4
#  Current loss 0.9984732866287231
#
# Epoch number 4
#  Current loss 0.9899908304214478
#
# Epoch number 4
#  Current loss 1.0252913236618042
#
# Epoch number 4
#  Current loss 1.019477367401123
#
# Epoch number 5
#  Current loss 0.9537124633789062
#
# Epoch number 5
#  Current loss 1.0099778175354004
#
# Epoch number 5
#  Current loss 0.9829220771789551
#
# Epoch number 5
#  Current loss 1.0222716331481934
#
# Epoch number 5
#  Current loss 1.0048801898956299
#
# Epoch number 5
#  Current loss 1.020004153251648
#
# Epoch number 5
#  Current loss 0.9991089105606079
#
# Epoch number 5
#  Current loss 0.9755720496177673
#
# Epoch number 6
#  Current loss 1.004385232925415
#
# Epoch number 6
#  Current loss 0.9475253820419312
#
# Epoch number 6
#  Current loss 0.9516138434410095
#
# Epoch number 6
#  Current loss 1.0217640399932861
#
# Epoch number 6
#  Current loss 0.9807755351066589
#
# Epoch number 6
#  Current loss 0.9957982897758484
#
# Epoch number 6
#  Current loss 1.0004193782806396
#
# Epoch number 6
#  Current loss 1.050042986869812
#
# Epoch number 7
#  Current loss 0.9969673156738281
#
# Epoch number 7
#  Current loss 1.0161714553833008
#
# Epoch number 7
#  Current loss 1.025244951248169
#
# Epoch number 7
#  Current loss 1.0300958156585693
#
# Epoch number 7
#  Current loss 1.0276002883911133
#
# Epoch number 7
#  Current loss 0.9651878476142883
#
# Epoch number 7
#  Current loss 0.9528443813323975
#
# Epoch number 7
#  Current loss 1.0034229755401611
#
# Epoch number 8
#  Current loss 1.0262898206710815
#
# Epoch number 8
#  Current loss 0.9857451915740967
#
# Epoch number 8
#  Current loss 1.0213918685913086
#
# Epoch number 8
#  Current loss 0.9806747436523438
#
# Epoch number 8
#  Current loss 1.0348551273345947
#
# Epoch number 8
#  Current loss 1.0111455917358398
#
# Epoch number 8
#  Current loss 1.0128105878829956
#
# Epoch number 8
#  Current loss 1.0030908584594727
#
# Epoch number 9
#  Current loss 0.9902921915054321
#
# Epoch number 9
#  Current loss 1.0242719650268555
#
# Epoch number 9
#  Current loss 1.012587547302246
#
# Epoch number 9
#  Current loss 1.0337084531784058
#
# Epoch number 9
#  Current loss 1.0072312355041504
#
# Epoch number 9
#  Current loss 0.9953447580337524
#
# Epoch number 9
#  Current loss 1.0049951076507568
#
# Epoch number 9
#  Current loss 1.0153099298477173
#
# Epoch number 10
#  Current loss 1.0110812187194824
#
# Epoch number 10
#  Current loss 1.0083258152008057
#
# Epoch number 10
#  Current loss 0.9796454310417175
#
# Epoch number 10
#  Current loss 1.0153039693832397
#
# Epoch number 10
#  Current loss 1.0250461101531982
#
# Epoch number 10
#  Current loss 1.0702731609344482
#
# Epoch number 10
#  Current loss 0.9956797361373901
#
# Epoch number 10
#  Current loss 1.0376055240631104
#
# Epoch number 11
#  Current loss 1.0176365375518799
#
# Epoch number 11
#  Current loss 1.000385046005249
#
# Epoch number 11
#  Current loss 0.9965050220489502
#
# Epoch number 11
#  Current loss 1.0206360816955566
#
# Epoch number 11
#  Current loss 1.035063624382019
#
# Epoch number 11
#  Current loss 1.007166862487793
#
# Epoch number 11
#  Current loss 0.957810640335083
#
# Epoch number 11
#  Current loss 0.9878697395324707
#
# Epoch number 12
#  Current loss 1.0049643516540527
#
# Epoch number 12
#  Current loss 0.9389411211013794
#
# Epoch number 12
#  Current loss 0.9869450926780701
#
# Epoch number 12
#  Current loss 1.0278875827789307
#
# Epoch number 12
#  Current loss 0.996272623538971
#
# Epoch number 12
#  Current loss 0.985459566116333
#
# Epoch number 12
#  Current loss 0.9879143238067627
#
# Epoch number 12
#  Current loss 1.0121935606002808
#
# Epoch number 13
#  Current loss 1.032244086265564
#
# Epoch number 13
#  Current loss 0.9911184906959534
#
# Epoch number 13
#  Current loss 1.0062848329544067
#
# Epoch number 13
#  Current loss 0.9880654811859131
#
# Epoch number 13
#  Current loss 1.0286785364151
#
# Epoch number 13
#  Current loss 0.983256459236145
#
# Epoch number 13
#  Current loss 1.009411334991455
#
# Epoch number 13
#  Current loss 0.9743650555610657
#
# Epoch number 14
#  Current loss 1.022826910018921
#
# Epoch number 14
#  Current loss 1.012824296951294
#
# Epoch number 14
#  Current loss 1.0176066160202026
#
# Epoch number 14
#  Current loss 0.9835487008094788
#
# Epoch number 14
#  Current loss 1.0172375440597534
#
# Epoch number 14
#  Current loss 1.0149511098861694
#
# Epoch number 14
#  Current loss 0.9692395925521851
#
# Epoch number 14
#  Current loss 0.9536725282669067
#
# Epoch number 15
#  Current loss 0.9743705987930298
#
# Epoch number 15
#  Current loss 1.0071768760681152
#
# Epoch number 15
#  Current loss 1.0031845569610596
#
# Epoch number 15
#  Current loss 0.974864661693573
#
# Epoch number 15
#  Current loss 0.9761954545974731
#
# Epoch number 15
#  Current loss 1.0382616519927979
#
# Epoch number 15
#  Current loss 1.0216127634048462
#
# Epoch number 15
#  Current loss 1.026705265045166
#
# Epoch number 16
#  Current loss 1.0189554691314697
#
# Epoch number 16
#  Current loss 1.0036113262176514
#
# Epoch number 16
#  Current loss 0.9866371154785156
#
# Epoch number 16
#  Current loss 0.9963639974594116
#
# Epoch number 16
#  Current loss 0.9804158210754395
#
# Epoch number 16
#  Current loss 1.0013561248779297
#
# Epoch number 16
#  Current loss 1.0125423669815063
#
# Epoch number 16
#  Current loss 0.9878546595573425
#
# Epoch number 17
#  Current loss 0.9801335334777832
#
# Epoch number 17
#  Current loss 0.9561058282852173
#
# Epoch number 17
#  Current loss 1.038865089416504
#
# Epoch number 17
#  Current loss 0.9837565422058105
#
# Epoch number 17
#  Current loss 0.9989463090896606
#
# Epoch number 17
#  Current loss 0.9845529794692993
#
# Epoch number 17
#  Current loss 1.0102581977844238
#
# Epoch number 17
#  Current loss 1.0161879062652588
#
# Epoch number 18
#  Current loss 0.9377226829528809
#
# Epoch number 18
#  Current loss 1.0263091325759888
#
# Epoch number 18
#  Current loss 1.0186244249343872
#
# Epoch number 18
#  Current loss 1.0110514163970947
#
# Epoch number 18
#  Current loss 0.9772117137908936
#
# Epoch number 18
#  Current loss 0.9568799138069153
#
# Epoch number 18
#  Current loss 1.0191795825958252
#
# Epoch number 18
#  Current loss 1.0027978420257568
#
# Epoch number 19
#  Current loss 0.9729609489440918
#
# Epoch number 19
#  Current loss 1.0170295238494873
#
# Epoch number 19
#  Current loss 0.9122005701065063
#
# Epoch number 19
#  Current loss 0.9892401099205017
#
# Epoch number 19
#  Current loss 1.0305118560791016
#
# Epoch number 19
#  Current loss 1.0040651559829712
#
# Epoch number 19
#  Current loss 0.9675009250640869
#
# Epoch number 19
#  Current loss 1.0130869150161743
#
# Epoch number 20
#  Current loss 0.9983716011047363
#
# Epoch number 20
#  Current loss 1.001893401145935
#
# Epoch number 20
#  Current loss 1.0054523944854736
#
# Epoch number 20
#  Current loss 1.0221209526062012
#
# Epoch number 20
#  Current loss 0.9175633192062378
#
# Epoch number 20
#  Current loss 1.0010969638824463
#
# Epoch number 20
#  Current loss 1.0109031200408936
#
# Epoch number 20
#  Current loss 0.9377783536911011
#
# Epoch number 21
#  Current loss 1.0023099184036255
#
# Epoch number 21
#  Current loss 0.9946726560592651
#
# Epoch number 21
#  Current loss 0.9952027201652527
#
# Epoch number 21
#  Current loss 0.9918425679206848
#
# Epoch number 21
#  Current loss 1.026524543762207
#
# Epoch number 21
#  Current loss 1.0104444026947021
#
# Epoch number 22
#  Current loss 0.9915665984153748
#
# Epoch number 22
#  Current loss 1.0107052326202393
#
# Epoch number 22
#  Current loss 1.012918472290039
#
# Epoch number 22
#  Current loss 0.994767427444458
#
# Epoch number 22
#  Current loss 1.014268159866333
#
# Epoch number 22
#  Current loss 0.9398561716079712
#
# Epoch number 22
#  Current loss 1.0208841562271118
#
# Epoch number 22
#  Current loss 0.9987324476242065
#
# Epoch number 23
#  Current loss 0.9911569356918335
#
# Epoch number 23
#  Current loss 1.001227617263794
#
# Epoch number 23
#  Current loss 1.0156691074371338
#
# Epoch number 23
#  Current loss 0.9916025996208191
#
# Epoch number 23
#  Current loss 1.0058693885803223
#
# Epoch number 23
#  Current loss 1.0099387168884277
#
# Epoch number 23
#  Current loss 1.003507137298584
#
# Epoch number 23
#  Current loss 1.0148755311965942
#
# Epoch number 24
#  Current loss 1.0088205337524414
#
# Epoch number 24
#  Current loss 0.9779878854751587
#
# Epoch number 24
#  Current loss 1.0187430381774902
#
# Epoch number 24
#  Current loss 1.0027133226394653
#
# Epoch number 24
#  Current loss 0.9797855615615845
#
# Epoch number 24
#  Current loss 1.0531508922576904
#
# Epoch number 24
#  Current loss 1.0133075714111328
#
# Epoch number 24
#  Current loss 0.9973669648170471
#
# Epoch number 25
#  Current loss 0.9759556651115417
#
# Epoch number 25
#  Current loss 0.9606223702430725
#
# Epoch number 25
#  Current loss 0.9992716312408447
#
# Epoch number 25
#  Current loss 0.9875310659408569
#
# Epoch number 25
#  Current loss 0.9980909824371338
#
# Epoch number 25
#  Current loss 0.9911099672317505
#
# Epoch number 25
#  Current loss 0.9859873056411743
#
# Epoch number 25
#  Current loss 0.9922177791595459
#
# Epoch number 26
#  Current loss 0.8846681118011475
#
# Epoch number 26
#  Current loss 0.9924525618553162
#
# Epoch number 26
#  Current loss 1.0040407180786133
#
# Epoch number 26
#  Current loss 0.9886125326156616
#
# Epoch number 26
#  Current loss 1.0568413734436035
#
# Epoch number 26
#  Current loss 0.9784994125366211
#
# Epoch number 26
#  Current loss 1.0034022331237793
#
# Epoch number 26
#  Current loss 1.007544755935669
#
# Epoch number 27
#  Current loss 1.0009815692901611
#
# Epoch number 27
#  Current loss 1.0131878852844238
#
# Epoch number 27
#  Current loss 0.9882528185844421
#
# Epoch number 27
#  Current loss 0.9976139068603516
#
# Epoch number 27
#  Current loss 0.988375723361969
#
# Epoch number 27
#  Current loss 0.9875447750091553
#
# Epoch number 27
#  Current loss 0.9863661527633667
#
# Epoch number 27
#  Current loss 0.9925295114517212
#
# Epoch number 28
#  Current loss 0.925937831401825
#
# Epoch number 28
#  Current loss 0.9900548458099365
#
# Epoch number 28
#  Current loss 1.0130016803741455
#
# Epoch number 28
#  Current loss 1.0101922750473022
#
# Epoch number 28
#  Current loss 1.0076026916503906
#
# Epoch number 28
#  Current loss 0.9382227659225464
#
# Epoch number 28
#  Current loss 0.9874542951583862
#
# Epoch number 28
#  Current loss 1.0044078826904297
#
# Epoch number 29
#  Current loss 0.9451679587364197
#
# Epoch number 29
#  Current loss 1.0196545124053955
#
# Epoch number 29
#  Current loss 0.9041891098022461
#
# Epoch number 29
#  Current loss 0.9872840642929077
#
# Epoch number 29
#  Current loss 0.9863856434822083
#
# Epoch number 29
#  Current loss 0.927932620048523
#
# Epoch number 29
#  Current loss 1.000666856765747
#
# Epoch number 29
#  Current loss 1.0019577741622925
#
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("model.pt"))

# %%
# Load the test dataset
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((224,224)),
                                                                      transforms.ToTensor(),
                                                                      transforms.Normalize(mean=[0.485], std=[0.229])
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)

# %%
# Print the sample outputs to view its dissimilarity
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
  x0, x1 , label = data
  concatenated = torch.cat((x0,x1),0)
  output1,output2 = model(x0.to(device),x1.to(device))
  eucledian_distance = F.pairwise_distance(output1, output2)
  if label==list_0:
    label="Orginial"
  else:
    label="Forged"
  imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
  counter=counter+1
  if counter ==20:
     break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Final Touch

# %% [markdown]
# Thats it guys ! I am limited by time , computational power and knowledge .to get standard accuracy . But anyway this is the working code of Siamese Neural Network and you can try it for your own applications and dataset.
#
# Paper Reference: https://arxiv.org/pdf/1707.02131.pdf
#
# Thanks to Gupta Blog : https://hackernoon.com/one-shot-learning-with-siamese-networks-in-pytorch-8ddaab10340e
